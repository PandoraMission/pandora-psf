# %% [markdown]
# - PSF (we could just remove this!?)
# - PRF (this is the fundamental object we need)
#
#
# ## PRF
# - evaluate the normalized flux per pixel as a numpy array
# - return an aperture given magnitude?
# - should it know about sensitivity? no?
# - should it know about wavelength? no?
#
#
# ## SpectrumPRF
# - all of the above?
# - needs to know about trace position
#
#
# Sensitivity should be separate?
# Makes PRF objects much more general
#
#
# - we want to stack into a scene
